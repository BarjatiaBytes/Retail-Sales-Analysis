# %%
# importing required libraries
import pandas as pd
import re
df = pd.read_csv('products.csv')

# %%
# checking for null values
df.isnull().sum()
# Out:
# product_id       0
# product_name     0
# price            0
# category_id      0
# class            0
# modify_date      0
# resistant        0
# is_allergic      0
# vitality_days    0
# dtype: int64

# %%
#converting column headers to snake case 
df.columns = df.columns.str.lower()# make them lower case
df.columns = df.columns.str.replace(' ','_') # add _ instead of space
df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'}) # aplly changes

# %%
#formatting date
df['modify_date'] = pd.to_datetime(df['modify_date'])#converting to datetime object
df['modify_date'] = df['modify_date'].dt.strftime('%Y-%m-%d')# simple

# %%
# rounding up the price column
df['price'] = df['price'].round(1)

# %%
df.head()
# Out:
#    product_id                product_name  price  category_id   class  \
# 0           1         Flour - Whole Wheat   74.3            3  Medium
# 1           2  Cookie Chocolate Chip With   91.2            3  Medium
# 2           3          Onions - Cippolini    9.1            9  Medium
# 3           4  Sauce - Gravy, Au Jus, Mix   54.3            9  Medium
# 4           5      Artichokes - Jerusalem   65.5            2     Low
#
#   modify_date resistant is_allergic  vitality_days
# 0  2018-02-16   Durable     Unknown            0.0
# 1  2017-02-12   Unknown     Unknown            0.0
# 2  2018-03-15      Weak       False          111.0
# 3  2017-07-16   Durable     Unknown            0.0
# 4  2017-08-16   Durable        True           27.0

# %%
# saving changes to the original file
df.to_csv('products.csv',index=False)

# %%
# importing sales data
df_sales = pd.read_csv('sales.csv')

# %%
df_sales = df_sales.drop(columns=['product_price.1'])

# %%
df_sales.head()
# Out:
#    sale_id  sales_person_id  customer_id  product_id  quantity  product_price  \
# 0        1                6        27039         381         7           44.2
# 1        2               16        25011          61         7           62.6
# 2        3               13        94024          23        24           79.0
# 3        4                8        73966         176        19           81.3
# 4        5               10        32653         310         9           80.0
#
#    gross_price  discount  net_price  sales_date    transaction_number
# 0        309.4       0.0     309.40  2018-02-05  FQL4S94E4ME1EZFTG42G
# 1        438.2       0.0     438.20  2018-02-02  12UGLX40DJ1A5DTFBHB8
# 2       1896.0       0.0    1896.00  2018-05-03  5DT8RCPL87KI5EORO7B0
# 3       1544.7       0.2    1235.76  2018-04-07  R3DR9MLD5NR76VO17ULE
# 4        720.0       0.0     720.00  2018-02-12  4BGS0Z5OMAZ8NDAFHHP3

# %%
#checking for null values
df_sales.isnull().sum()
# Out:
# sale_id               0
# sales_person_id       0
# customer_id           0
# product_id            0
# quantity              0
# product_price         0
# product_price.1       0
# gross_price           0
# discount              0
# net_price             0
# sales_date            0
# transaction_number    0
# dtype: int64

# %%
# row count
print(df_sales.shape[0])
# Out:
# 6690599

# %%
# coverting column headers to snake case
def to_snake_case(name):
    s1 = re.sub(r'(.)([A-Z])', r'\1_\2', name)#inserts an underscore (_) before every capital letter (except the very first) to separate the words
    return s1.lower()

original_col = df_sales.columns.tolist()
snake_case_col = [to_snake_case(col) for col in original_col]

df_sales.columns = snake_case_col

# %%
# formatting sales date
df_sales['sales_date'] = pd.to_datetime(df_sales['sales_date'])#converting to datetime object
df_sales['sales_date'] = df_sales['sales_date'].dt.strftime('%Y-%m-%d')# simple

# %%
#droping rows where sales date is not mentioned
df_sales = df_sales.dropna(subset=['sales_date'])

# %%
df_sales.head()
# Out:
#    sales_id  sales_person_id  customer_id  product_id  quantity  \
# 0         1                6        27039         381         7
# 1         2               16        25011          61         7
# 2         3               13        94024          23        24
# 3         4                8        73966         176        19
# 4         5               10        32653         310         9
#
#    product_price  gross_price  discount  net_price  sales_date  \
# 0           44.2        309.4       0.0     309.40  2018-02-05
# 1           62.6        438.2       0.0     438.20  2018-02-02
# 2           79.0       1896.0       0.0    1896.00  2018-05-03
# 3           81.3       1544.7       0.2    1235.76  2018-04-07
# 4           80.0        720.0       0.0     720.00  2018-02-12
#
#      transaction_number
# 0  FQL4S94E4ME1EZFTG42G
# 1  12UGLX40DJ1A5DTFBHB8
# 2  5DT8RCPL87KI5EORO7B0
# 3  R3DR9MLD5NR76VO17ULE
# 4  4BGS0Z5OMAZ8NDAFHHP3

# %%
# Adding price column to sales dataframe
df_sales = pd.merge(           #combining dataframes on commonkey
    df_sales,
    df[['product_id','price']],
    on = 'product_id',
    how = 'left'
)
# Reordering the column 
quantity_index = df_sales.columns.get_loc('quantity')

cols = df_sales.columns.to_list() # converting column into a list

cols.insert(quantity_index + 1 , cols.pop(cols.index('price'))) # specifing postion

# %%
# apllying the ordered lsit
df_sales = df_sales[cols]

# %%
df_sales.head()
# Out:
#    sales_id  sales_person_id  customer_id  product_id  quantity  price  \
# 0         1                6        27039         381         7   44.2
# 1         2               16        25011          61         7   62.6
# 2         3               13        94024          23        24   79.0
# 3         4                8        73966         176        19   81.3
# 4         5               10        32653         310         9   80.0
#
#    product_price  gross_price  discount  net_price  sales_date  \
# 0           44.2        309.4       0.0     309.40  2018-02-05
# 1           62.6        438.2       0.0     438.20  2018-02-02
# 2           79.0       1896.0       0.0    1896.00  2018-05-03
# 3           81.3       1544.7       0.2    1235.76  2018-04-07
# 4           80.0        720.0       0.0     720.00  2018-02-12
#
#      transaction_number
# 0  FQL4S94E4ME1EZFTG42G
# 1  12UGLX40DJ1A5DTFBHB8
# 2  5DT8RCPL87KI5EORO7B0
# 3  R3DR9MLD5NR76VO17ULE
# 4  4BGS0Z5OMAZ8NDAFHHP3

# %%
# calculating gross price

df_sales.rename(columns={'price': 'product_price'}, inplace=True)# Rename price to product_price

df_sales['gross_price'] = (df_sales['quantity'] * df_sales['product_price']).round(2)#Calculating gross price and rounding up

df_sales.drop(columns=['total_price'], inplace=True)# Droping the total_price column

# Reordering columns

cols = df_sales.columns.tolist()#column list

product_price_index = cols.index('product_price')#position of product_price

cols.insert(product_price_index + 1,
            cols.pop(cols.index('gross_price')))# Move gross_price to right after product_price

# Applying the new column order
df_sales = df_sales[cols]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 5
#       1 # calculating gross price
#       3 df_sales.rename(columns={'price': 'product_price'}, inplace=True)# Rename price to product_price
# ----> 5 df_sales['gross_price'] = (df_sales['quantity'] * df_sales['product_price']).round(2)#Calculating gross price and rounding up
#       7 df_sales.drop(columns=['total_price'], inplace=True)# Droping the total_price column
#       9 # Reordering columns
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:206, in OpsMixin.__rmul__(self, other)
#     204 @unpack_zerodim_and_defer("__rmul__")
#     205 def __rmul__(self, other):
# --> 206     return self._arith_method(other, roperator.rmul)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7910, in DataFrame._arith_method(self, other, op)
#    7907 axis: Literal[1] = 1  # only relevant for Series other case
#    7908 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
# -> 7910 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7912 with np.errstate(all="ignore"):
#    7913     new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8211, in DataFrame._align_for_op(self, other, axis, flex, level)
#    8204         if not left.axes[axis].equals(right.index):
#    8205             raise ValueError(
#    8206                 "Operands are not aligned. Do "
#    8207                 "`left, right = left.align(right, axis=1, copy=False)` "
#    8208                 "before operating."
#    8209             )
# -> 8211     left, right = left.align(
#    8212         right,
#    8213         join="outer",
#    8214         axis=axis,
#    8215         level=level,
#    8216         copy=False,
#    8217     )
#    8218     right = left._maybe_align_series_as_frame(right, axis)
#    8220 return left, right
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:10447, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#   10434     left, _right, join_index = self._align_frame(
#   10435         other,
#   10436         join=join,
#    (...)
#   10443         fill_axis=fill_axis,
#   10444     )
#   10446 elif isinstance(other, ABCSeries):
# > 10447     left, _right, join_index = self._align_series(
#   10448         other,
#   10449         join=join,
#   10450         axis=axis,
#   10451         level=level,
#   10452         copy=copy,
#   10453         fill_value=fill_value,
#   10454         method=method,
#   10455         limit=limit,
#   10456         fill_axis=fill_axis,
#   10457     )
#   10458 else:  # pragma: no cover
#   10459     raise TypeError(f"unsupported type: {type(other)}")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:10590, in NDFrame._align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#   10588 if lidx is not None:
#   10589     bm_axis = self._get_block_manager_axis(1)
# > 10590     fdata = fdata.reindex_indexer(join_index, lidx, axis=bm_axis)
#   10592 if copy and fdata is self._mgr:
#   10593     fdata = fdata.copy()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:674, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     672 # some axes don't allow reindexing with dups
#     673 if not allow_dups:
# --> 674     self.axes[axis]._validate_can_reindex(indexer)
#     676 if axis >= self.ndim:
#     677     raise IndexError("Requested axis not found in manager")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4321, in Index._validate_can_reindex(self, indexer)
#    4319 # trying to reindex on an axis with duplicates
#    4320 if not self._index_as_unique and len(indexer):
# -> 4321     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
# calculating net price by multiplying gross_price with discount

df_sales['net_price'] = (df_sales['gross_price'] * (1-df_sales['discount'])).round(2)

# reordering columns
cols_2 = df_sales.columns.tolist()

discount_index = cols_2.index('discount')

cols_2.insert(discount_index + 1,
             cols_2.pop(cols_2.index('net_price')))

# apllying new column order
df_sales = df_sales[cols_2]

# %%
df_sales.rename(columns={'sales_id': 'sale_id'}, inplace=True)

# %%
df_sales.head()
# Out:
#    sale_id  sales_person_id  customer_id  product_id  quantity  product_price  \
# 0        1                6        27039         381         7           44.2
# 1        2               16        25011          61         7           62.6
# 2        3               13        94024          23        24           79.0
# 3        4                8        73966         176        19           81.3
# 4        5               10        32653         310         9           80.0
#
#    product_price  gross_price  discount  net_price  sales_date  \
# 0           44.2        309.4       0.0     309.40  2018-02-05
# 1           62.6        438.2       0.0     438.20  2018-02-02
# 2           79.0       1896.0       0.0    1896.00  2018-05-03
# 3           81.3       1544.7       0.2    1235.76  2018-04-07
# 4           80.0        720.0       0.0     720.00  2018-02-12
#
#      transaction_number
# 0  FQL4S94E4ME1EZFTG42G
# 1  12UGLX40DJ1A5DTFBHB8
# 2  5DT8RCPL87KI5EORO7B0
# 3  R3DR9MLD5NR76VO17ULE
# 4  4BGS0Z5OMAZ8NDAFHHP3

# %%
df_sales['net_price'].describe()
# Out:
# count    6.690599e+06
# mean     6.410663e+02
# std      5.470737e+02
# min      0.000000e+00
# 25%      1.806000e+02
# 50%      4.908000e+02
# 75%      9.840000e+02
# max      2.497500e+03
# Name: net_price, dtype: float64

# %%
#saving changes to the original file
df_sales.to_csv('sales.csv',index=False)

# %%
# working with category table
df_ca = pd.read_csv('categories.csv')

# %%
# formatting column names to snake case
df_ca.columns = df_ca.columns.str.lower()
df_ca.columns = df_ca.columns.str.replace(' ','_')

# %%
#saving changes to the original csv file
df_ca.to_csv('categories.csv',index=False)
# Out:
# Index(['category_id', 'category_name'], dtype='object')

# %%
#working with cities table
df_ct = pd.read_csv('cities.csv')

# %%
# formatting column names to snake case
df_ct.columns = df_ct.columns.str.lower()
df_ct.columns = df_ct.columns.str.replace(' ','_')

# %%
#saving changes to the original csv file
df_ct.to_csv('cities.csv',index=False)

# %%
# working with countries table
df_co = pd.read_csv('countries.csv')

# %%
# formatting column names to snake case
df_co.columns = df_co.columns.str.lower()
df_co.columns = df_co.columns.str.replace(' ','_')

# %%
df_co.head()
# Out:
#    country_id country_name country_code
# 0           1      Armenia           AN
# 1           2       Canada           FO
# 2           3       Belize           MK
# 3           4       Uganda           LV
# 4           5     Thailand           VI

# %%
#saving changes to the original csv file
df_co.to_csv('countries.csv',index=False)

# %%
# working with customers table
df_cus = pd.read_csv('customers.csv')

# %%
# formatting column names to snake case
df_cus.columns = df_cus.columns.str.lower()
df_cus.columns = df_cus.columns.str.replace(' ','_')

# %%
df_cus.head()
# Out:
#    customer_id first_name middle_initial last_name  city_id  \
# 0            1   Stefanie              Y      Frye       79
# 1            2      Sandy              T     Kirby       96
# 2            3        Lee              T     Zhang       55
# 3            4     Regina              S     Avery       40
# 4            5     Daniel              S    Mccann        2
#
#                         address
# 0                 97 Oak Avenue
# 1        52 White First Freeway
# 2       921 White Fabien Avenue
# 3                 75 Old Avenue
# 4  283 South Green Hague Avenue

# %%
#saving changes to the original csv file
df_cus.to_csv('customers.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #saving changes to the original csv file
# ----> 2 df_cus.to_csv('customers.csv',index=False)
#
# NameError: name 'df_cus' is not defined

# %%
#working with employees table
df_emp = pd.read_csv('employees.csv')

# %%
# formatting column names to snake case
df_emp.columns = df_emp.columns.str.lower()
df_emp.columns = df_emp.columns.str.replace(' ','_')

# %%
# coverting column headers to snake case
def to_snake_case(name):
    s1 = re.sub(r'(.)([A-Z])', r'\1_\2', name)#inserts an underscore (_) before every capital letter (except the very first) to separate the words
    return s1.lower()

original_col = df_emp.columns.tolist()
snake_case_col = [to_snake_case(col) for col in original_col]

df_emp.columns = snake_case_col

# %%
# formatting hire date
df_emp['hire_date'] = pd.to_datetime(df_emp['hire_date']) # converting to datetime obeject
df_emp['hire_date'] = df_emp['hire_date'].dt.strftime('%Y-%m-%d')# simple

# %%
# formatting hire date
df_emp['birth_date'] = pd.to_datetime(df_emp['birth_date']) # converting to datetime obeject
df_emp['birth_date'] = df_emp['birth_date'].dt.strftime('%Y-%m-%d')# simple

# %%
df_emp.head()
# Out:
#    employee_id first_name middle_initial last_name  birth_date gender  \
# 0            1     Nicole              T    Fuller  1981-03-07      F
# 1            2  Christine              W    Palmer  1968-01-25      F
# 2            3      Pablo              Y     Cline  1963-02-09      M
# 3            4    Darnell              O   Nielsen  1989-02-06      M
# 4            5    Desiree              L    Stuart  1963-05-03      F
#
#    city_id   hire_date
# 0       80  2011-06-20
# 1        4  2011-04-27
# 2       70  2012-03-30
# 3       39  2014-03-06
# 4       23  2014-11-16

# %%
# calculating employee age
from datetime import date

df_emp['birth_date'] = pd.to_datetime(df_emp['birth_date'])
today = pd.to_datetime(date.today()) # fecthing today's date

df_emp['age'] = ((today - df_emp['birth_date']).dt.days/365.25).astype(int) # subtracting today's date woth birth date

# reordering the columns
birth_date_index = df_emp.columns.get_loc('birth_date') # index position stored
cols = df_emp.columns.tolist() # list of columns

#insert the column right next to birth_date
cols.insert(birth_date_index + 1, cols.pop(cols.index('age')))
df_emp = df_emp[cols]

# %%
df_emp.head()
# Out:
#    employee_id first_name middle_initial last_name birth_date  age gender  \
# 0            1     Nicole              T    Fuller 1981-03-07   44      F
# 1            2  Christine              W    Palmer 1968-01-25   57      F
# 2            3      Pablo              Y     Cline 1963-02-09   62      M
# 3            4    Darnell              O   Nielsen 1989-02-06   36      M
# 4            5    Desiree              L    Stuart 1963-05-03   62      F
#
#    city_id   hire_date
# 0       80  2011-06-20
# 1        4  2011-04-27
# 2       70  2012-03-30
# 3       39  2014-03-06
# 4       23  2014-11-16

# %%
#saving changes to the original csv file
df_emp.to_csv('employees.csv',index=False)
